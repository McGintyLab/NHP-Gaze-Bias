# %% [markdown]
# # Absolute GLAM Fit
# This notebook estimates parameters for the GLAM to half of the data and then simulates the held out trials. For quantification of the absolute fit, see the _GLAM_OOS_ModelFit.mlx_ analysis script in this repository.

# %% [markdown]
# ## Housekeeping
# ### Load Necessary Libraries

# %%
import warnings
from os.path import join

import glambox as gb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Ignore future warnings re: multi-indexing
warnings.simplefilter(action="ignore", category=FutureWarning)

# Fix for compilation error (as per Felix Molter)
# https://stackoverflow.com/a/51312739
import theano

theano.config.gcc.cxxflags = "-Wno-c++11-narrowing"
theano.config.cxx
# Out:
# '/usr/bin/clang++'

# %% [markdown]
# ### Set MCMC Sampling Parameters

# %%
# Set MCMC parameters
n_tune = 5000
n_draws = 5000
n_chains = 2

# %% [markdown]
# ### Set Other Miscellaneous Variables

# %%
# Set error weight
error_weight = 0.01

# set random seed for replicability
np.random.seed(31)

# set monkey ID
monkeys = ["MonkeyC", "MonkeyK"]

# %% [markdown]
# ### Set Data Grouping Flag
# This notebook can be run treating each monkey as a subject, or each session as a subject. The data for the two versions are are in separate excel files. The only difference between the two is the input to the 'subject' field.
#
# **To select the correct input file, set the variable DATA_GROUPING to either 'session' or 'monkey'.** 'monkey' is the default option

# %%
DATA_GROUPING = "monkey"

# %%
data = pd.read_csv("GLAMdata_"+ DATA_GROUPING + ".csv")

# display the unique subject numbers to make sure you set the desired data grouping flag
print(data.subject.unique())
# Out:
# [0 1]

# %% [markdown]
# #### Split data into even and odd trials

# %%
data_odd = pd.DataFrame()
data_even = pd.DataFrame()
subIds = data.subject.unique()
for s in subIds:
    tmp_odd = data.loc[(data["trial"] % 2 == 1) & (data["subject"] == s)]
    tmp_even = data.loc[(data["trial"] % 2 == 0) & (data["subject"] == s)]
    data_even = data_even.append(tmp_even)
    data_odd = data_odd.append(tmp_odd)

# %% [markdown]
# ## Parameter Estimation
# This section uses the even-numbered trials to estimate the GLAM parameters.

# %%
# initialize GLAM model object with the even-numbered trials
model = gb.GLAM(data=data_even)

# %%
# define model. 
model.make_model(kind="individual", t0_val=0, error_weight=error_weight)
# Out:
# Generating single subject models for 2 subjects...

# %%
# fit model to the data
model.fit(tune=n_tune, draws=n_draws, chains=n_chains)
# Out:
# Fitting 2 model(s) using MCMC...
#   Fitting model 1 of 2...
# Multiprocess sampling (2 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau]
# >Metropolis: [s]
# >Metropolis: [gamma]
# >Metropolis: [v]
# Sampling 2 chains: 100%|██████████████| 20000/20000 [01:42<00:00, 194.49draws/s]
# The number of effective samples is smaller than 10% for some parameters.
#   Fitting model 2 of 2...
# Multiprocess sampling (2 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau]
# >Metropolis: [s]
# >Metropolis: [gamma]
# >Metropolis: [v]
# Sampling 2 chains: 100%|██████████████| 20000/20000 [01:34<00:00, 211.31draws/s]
# The number of effective samples is smaller than 10% for some parameters.
# /!\ Automatically setting parameter precision...

# %%
# Show parameter estimates
# Monkey C is row 0 and Monkey K is row 1.
model.estimates
# Out:
#    gamma  gamma_hpd_2.5  gamma_hpd_97.5      s  s_hpd_2.5  s_hpd_97.5  \
# 0  0.261       0.235689        0.292552  0.239   0.236236    0.242568
# 1  0.157       0.136062        0.185365  0.221   0.217697    0.224719
#
#    subject   t0  t0_hpd_2.5  t0_hpd_97.5    tau  tau_hpd_2.5  tau_hpd_97.5  \
# 0        0  0.0         0.0          0.0  0.323     0.308622      0.329663
# 1        1  0.0         0.0          0.0  0.351     0.341670      0.362897
#
#        v  v_hpd_2.5  v_hpd_97.5
# 0  2.604   2.592108    2.622529
# 1  2.521   2.505730    2.535262

# %% [markdown]
# ## Out-of-Sample Simulations
# This section uses the estimated parameters to simulate each of the held-out (odd-numbered) trials. See 'GLAM_OOS_ModelFit.mlx' in the _Matlab_ folder of this repository for visualization and assessment of the out-of-sample simulations' goodness-of-fit.

# %%
# swap out the even-numbered trials with the held-out odd trials. 
model.exchange_data(new_data=data_odd)
# Out:
# Replaced attached data (15176 trials) with new data (15175 trials)...

# %%
# simulate each of the held-out trials 10x
model.predict(n_repeats=10, error_weight=error_weight)
# Out:
#   0%|                                         | 2/15175 [00:00<13:21, 18.94it/s]
# Generating predictions for 15175 trials (10 repeats each)...
# 100%|█████████████████████████████████████| 15175/15175 [13:18<00:00, 19.00it/s]

# %% [markdown]
# ### Visualize Results
# This produces graphs using the GLAM's built in plotting functions. The visualization shown in the manuscript was generated using the _GLAM_OOS_ModelFit.mlx_ file. The mat file loaded by that script uses data exported from python

# %%
def plot_psychometric(bar_data, line_data=None, ax=None):
    """
    Plots the probability of choosing item 0 as a function of relative value (`item_value_0` - `item_value_1`).
    """
    if ax is None:
        ax = plt.gca()

    for kind, data in zip(["bar", "line"], [bar_data, line_data]):
        if data is None:
            continue
        data = data.copy()
        data["value_diff"] = data["item_value_0"] - data["item_value_1"]
        data["choose0"] = data["choice"] == 0
        means = data.groupby("value_diff")["choose0"].mean()

        if kind == "bar":
            ax.bar(x=means.index, height=means.values, color="white", edgecolor="black")
        elif kind == "line":
            ax.plot(means.index, means.values, "--o", alpha=0.7)
    ax.set_xticks(means.index)
    ax.set_xticklabels(means.index, rotation=90)
    ax.set_xlabel("Value 0 - Value 1")
    ax.set_ylabel("P(Choose 0)")

    return ax

# %%
def plot_rt_by_difficulty(bar_data, line_data=None, ax=None):
    """
    Plots mean RT by difficulty (maximum - minimum item value).s
    """
    if ax is None:
        ax = plt.gca()

    for kind, data in zip(["bar", "line"], [bar_data, line_data]):
        if data is None:
            continue
        data = data.copy()
        data["difficulty"] = np.abs(data["item_value_0"] - data["item_value_1"])
        means = data.groupby("difficulty")["rt"].mean()

        if kind == "bar":
            ax.bar(x=means.index, height=means.values, color="white", edgecolor="black")
        elif kind == "line":
            ax.plot(means.index, means.values, "--o", alpha=0.7)
    ax.set_xticks(means.index)
    ax.set_xticklabels(means.index, rotation=90)
    ax.set_xlabel("Difficulty\n(Best value - worst value)")
    ax.set_ylabel("Response time (s)")

    return ax

# %%
for i, monkey in enumerate(monkeys):
    fig, axs = gb.plots.plot_behaviour_aggregate(
        bar_data=data_odd.loc[data_odd["id"] == monkey],
        line_data=[model.prediction.loc[model.prediction["id"] == monkey]],
        line_labels=["GLAM"],
    )
    # New RT plot
    axs[0].clear()
    axs[0] = plot_rt_by_difficulty(
        data_odd.loc[data_odd["id"] == monkey],
        model.prediction.loc[model.prediction["id"] == monkey],
        ax=axs[0],
        )
    axs[0].set_ylim(0, 0.75)
    # New choice curve plot
    axs[1].clear()
    axs[1] = plot_psychometric(
        data_odd.loc[data_odd["id"] == monkey],
        model.prediction.loc[model.prediction["id"] == monkey],
        ax=axs[1],
        )
    axs[1].set_ylim(0, 1)

    fig.suptitle(monkey.capitalize(), y=1.02)
# Out:
# 2
# 2
# 2
# 2
